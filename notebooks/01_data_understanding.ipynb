# %%
! pip install pandas numpy matplotlib seaborn pathlib

# %%
from pathlib import Path
import pandas as pd

file_path = Path("C:\\Users\\DVK\\Desktop\\Amazon_decade_Sales_project\\data\\amazon_india_complete_2015_2025.csv")
amazon_india_2015_2025 = pd.read_csv(file_path)
amazon_india_2015_2025.head()
# Out:
#       transaction_id  order_date         customer_id   product_id  \
# 0  TXN_2023_00063013  2023-07-23  CUST_2023_00018393  PROD_000454
# 1  TXN_2021_00064486  20-07-2021  CUST_2015_00002865  PROD_000579
# 2  TXN_2017_00065617  2017-11-16  CUST_2016_00004057  PROD_000295
# 3  TXN_2020_00054393  2020-05-04  CUST_2020_00014574  PROD_001654
# 4  TXN_2018_00071646  2018-10-09  CUST_2018_00006275  PROD_000095
#
#                         product_name     category  subcategory      brand  \
# 0                Vivo Y95 64GB Black  Electronics  Smartphones       Vivo
# 1        Realme Realme 3 128GB Black  Electronics  Smartphones     Realme
# 2                  Vivo V7 32GB Blue  Electronics  Smartphones       Vivo
# 3  Alienware Pavilion 4GB RAM Silver  Electronics      Laptops  Alienware
# 4    Motorola Moto X Play 16GB White  Electronics  Smartphones   Motorola
#
#   original_price_inr  discount_percent  ...  is_festival_sale  festival_name  \
# ...

# %%
amazon_india_2015_2025.shape
# Out:
# (1127609, 34)

# %%
amazon_india_2015_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1127609 entries, 0 to 1127608
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   transaction_id          1127609 non-null  object
#  1   order_date              1127609 non-null  object
#  2   customer_id             1127609 non-null  object
#  3   product_id              1127609 non-null  object
#  4   product_name            1127609 non-null  object
#  5   category                1127609 non-null  object
#  6   subcategory             1127609 non-null  object
#  7   brand                   1127609 non-null  object
#  8   original_price_inr      1127609 non-null  object
#  9   discount_percent        1127609 non-null  float64
#  10  discounted_price_inr    1127609 non-null  float64
#  11  quantity                1127609 non-null  int64
#  12  subtotal_inr            1127609 non-null  float64
# ...

# %%
amazon_india_2015_2025.columns
# Out:
# Index(['transaction_id', 'order_date', 'customer_id', 'product_id',
#        'product_name', 'category', 'subcategory', 'brand',
#        'original_price_inr', 'discount_percent', 'discounted_price_inr',
#        'quantity', 'subtotal_inr', 'delivery_charges', 'final_amount_inr',
#        'customer_city', 'customer_state', 'customer_tier',
#        'customer_spending_tier', 'customer_age_group', 'payment_method',
#        'delivery_days', 'delivery_type', 'is_prime_member', 'is_festival_sale',
#        'festival_name', 'customer_rating', 'return_status', 'order_month',
#        'order_year', 'order_quarter', 'product_weight_kg', 'is_prime_eligible',
#        'product_rating'],
#       dtype='object')

# %%
amazon_india_2015_2025.dtypes
# Out:
# transaction_id             object
# order_date                 object
# customer_id                object
# product_id                 object
# product_name               object
# category                   object
# subcategory                object
# brand                      object
# original_price_inr         object
# discount_percent          float64
# discounted_price_inr      float64
# quantity                    int64
# subtotal_inr              float64
# delivery_charges          float64
# final_amount_inr          float64
# customer_city              object
# customer_state             object
# customer_tier              object
# customer_spending_tier     object
# customer_age_group         object
# payment_method             object
# delivery_days              object
# delivery_type              object
# is_prime_member            object
# is_festival_sale           object
# festival_name              object
# customer_rating            object
# ...

# %%
amazon_india_2015_2025.describe()
# Out:
#        discount_percent  discounted_price_inr      quantity  subtotal_inr  \
# count      1.127609e+06          1.127609e+06  1.127609e+06  1.127609e+06
# mean       1.742035e+01          5.454134e+04  1.250063e+00  6.818740e+04
# std        2.055377e+01          4.582480e+04  5.365034e-01  6.893407e+04
# min        0.000000e+00          3.443300e+02  1.000000e+00  3.443300e+02
# 25%        0.000000e+00          2.278069e+04  1.000000e+00  2.521799e+04
# 50%        1.037000e+01          3.800119e+04  1.000000e+00  4.473182e+04
# 75%        2.841000e+01          7.410332e+04  1.000000e+00  8.852179e+04
# max        7.000000e+01          4.207048e+05  3.000000e+00  1.262114e+06
#
#        delivery_charges  final_amount_inr   order_month    order_year  \
# count      1.037408e+06      1.127609e+06  1.127609e+06  1.127609e+06
# mean       3.084611e-04      6.818740e+04  6.940627e+00  2.020637e+03
# std        1.110782e-01      6.893407e+04  3.539183e+00  2.690906e+00
# ...

# %%
amazon_india_2015_2025.describe(include='object')
# Out:
#            transaction_id  order_date         customer_id   product_id  \
# count             1127609     1127609             1127609      1127609
# unique            1127609       14414              354969         2004
# top     TXN_2023_00063013  2020-12-02  CUST_2015_00003928  PROD_001935
# freq                    1         543                  27         2916
#
#                product_name     category  subcategory    brand  \
# count               1127609      1127609      1127609  1127609
# unique                 1974            5            6       29
# top     Garmin Watch Deluxe  Electronics  Smartphones  Samsung
# freq                   2916      1126726       827177   222664
#
#        original_price_inr customer_city  ... customer_age_group  \
# count             1127609       1127609  ...             992294
# unique              46185            50  ...                  5
# top              45363.47        Mumbai  ...              26-35
# ...

# %%
amazon_india_2015_2025.isnull().sum()
# Out:
# transaction_id                 0
# order_date                     0
# customer_id                    0
# product_id                     0
# product_name                   0
# category                       0
# subcategory                    0
# brand                          0
# original_price_inr             0
# discount_percent               0
# discounted_price_inr           0
# quantity                       0
# subtotal_inr                   0
# delivery_charges           90201
# final_amount_inr               0
# customer_city                  0
# customer_state                 0
# customer_tier                  0
# customer_spending_tier         0
# customer_age_group        135315
# payment_method                 0
# delivery_days                  0
# delivery_type                  0
# is_prime_member                0
# is_festival_sale               0
# festival_name             777736
# customer_rating           341696
# return_status                  0
# ...

# %%
amazon_india_2015_2025.nunique()
# Out:
# transaction_id            1127609
# order_date                  14414
# customer_id                354969
# product_id                   2004
# product_name                 1974
# category                        5
# subcategory                     6
# brand                          29
# original_price_inr          46185
# discount_percent             6502
# discounted_price_inr       605861
# quantity                        3
# subtotal_inr               629180
# delivery_charges                2
# final_amount_inr           629180
# customer_city                  50
# customer_state                 15
# customer_tier                   4
# customer_spending_tier          3
# customer_age_group              5
# payment_method                  7
# delivery_days                  13
# delivery_type                   3
# is_prime_member                 8
# is_festival_sale                8
# festival_name                   8
# customer_rating                21
# ...

# %%
amazon_india_2015_2025['customer_city'].value_counts()
# Out:
# customer_city
# Mumbai           140536
# Delhi            122365
# Bangalore        101416
# Chennai           83646
# Pune              67703
# Kolkata           65767
# Ahmedabad         50861
# Hyderabad         44573
# Jaipur            40453
# Surat             40400
# Nagpur            37211
# Kanpur            34334
# Lucknow           34077
# Indore            33592
# Coimbatore        26695
# Kochi             24940
# Visakhapatnam     22167
# Patna             21339
# Vadodara          21078
# Bhubaneswar       20472
# Chandigarh        19575
# Ludhiana          18891
# Saharanpur         6705
# Meerut             6641
# Bareilly           6590
# Aligarh            6407
# Allahabad          6030
# Varanasi           5897
# Gorakhpur          5867
# Moradabad          5855
# New Delhi           304
# Mumbai              304
# Kolkata             294
# Bombay              289
# Banglore            287
# KOLKATA             285
# CHENNAI             285
# ...

# %%
amazon_india_2015_2025.sample(30)
# Out:
#             transaction_id  order_date         customer_id   product_id  \
# 375486   TXN_2025_00065507  2025-11-08  CUST_2025_00022434  PROD_000442
# 238058   TXN_2023_00028542  2023-03-10  CUST_2023_00014504  PROD_000302
# 1051849  TXN_2022_00004813  2022-01-09  CUST_2020_00040506  PROD_000512
# 342645   TXN_2023_00074517  2023-08-30  CUST_2016_00010595  PROD_000293
# 125334   TXN_2020_00072712  2020-07-30  CUST_2019_00001191  PROD_000097
# 497658   TXN_2022_00030207  2022-04-01  CUST_2021_00032794  PROD_001037
# 51514    TXN_2019_00094253  2019-10-05  CUST_2019_00010017  PROD_001892
# 927831   TXN_2021_00002949  2021-01-08  CUST_2017_00021387  PROD_000251
# 584155   TXN_2020_00087394  2020-09-12  CUST_2020_00017264  PROD_000584
# 299543   TXN_2019_00097862  2019-11-15  CUST_2019_00029899  PROD_000108
# 113625   TXN_2021_00035803  2021-04-01  CUST_2021_00013056  PROD_001567
# 933421   TXN_2019_00119408  2019-12-10  CUST_2019_00040912  PROD_000391
# ...

# %%
amazon_india_2015_2025.duplicated().sum()
# Out:
# np.int64(0)

# %%
amazon_india_2015_2025['order_date'].head(30)
# Out:
# 0     2023-07-23
# 1     20-07-2021
# 2     2017-11-16
# 3     2020-05-04
# 4     2018-10-09
# 5     2016-06-22
# 6     2019-10-22
# 7     2020-05-24
# 8     2022-03-10
# 9     2017-09-05
# 10    2018-12-19
# 11    2019-01-07
# 12    2020-12-25
# 13    2017-11-24
# 14    2018-09-22
# 15    2015-10-08
# 16    2022-02-27
# 17    2025-09-01
# 18    2017-06-20
# 19    2020-05-17
# 20    2019-04-26
# 21    02-12-2023
# 22    2021-01-22
# 23    2020-08-02
# 24    12/10/2017
# 25    29-04-2018
# 26    2020-12-26
# 27    2025-08-24
# 28    2016-01-02
# 29    2025-02-04
# Name: order_date, dtype: object

# %%
amazon_india_2015_2025['original_price_inr'].head(60)
# Out:
# 0       27340.84
# 1       32907.49
# 2      47,052.18
# 3      238725.44
# 4       25970.76
# 5       21541.01
# 6       39859.05
# 7      105554.58
# 8       26198.55
# 9      121800.87
# 10     144593.95
# 11      32101.77
# 12      36863.54
# 13      43614.86
# 14      76298.72
# 15     117289.33
# 16      47281.46
# 17       23082.2
# 18      25596.32
# 19      33539.59
# 20    ₹47,371.51
# 21      72975.05
# 22     392777.17
# 23      32653.28
# 24      22222.75
# 25      72618.91
# 26    ₹70,765.53
# 27       25535.5
# 28      52750.75
# 29       8231.71
# 30      65858.34
# 31      78981.32
# 32     116225.52
# 33      41452.69
# 34      89231.09
# 35       51502.9
# 36      52029.25
# 37      41404.07
# 38     227208.08
# 39      27092.49
# 40      28276.62
# 41      55538.72
# 42      21196.36
# 43      119456.0
# 44      31043.54
# 45      30943.32
# 46      42642.37
# 47     135540.55
# 48       56370.4
# 49     158433.75
# 50     147489.17
# 51      40438.41
# ...

# %%
amazon_india_2015_2025['product_rating'].sample(20)
# Out:
# 953664     4.0
# 476193     4.2
# 144365     4.2
# 1046653    3.8
# 450668     3.6
# 895736     3.8
# 47615      4.4
# 187025     3.4
# 794123     3.6
# 583325     3.7
# 313035     3.8
# 321085     4.0
# 169256     4.5
# 374858     3.3
# 710764     4.6
# 403824     3.3
# 1043272    4.6
# 4972       3.3
# 1098080    3.8
# 324441     4.6
# Name: product_rating, dtype: float64

# %%
amazon_india_2015_2025['customer_city'].head(20)
# Out:
# 0       Kolkata
# 1      Ludhiana
# 2     Bangalore
# 3     Bangalore
# 4         Kochi
# 5        Mumbai
# 6         Delhi
# 7        Mumbai
# 8       Kolkata
# 9        Mumbai
# 10    Bangalore
# 11    Bangalore
# 12      Aligarh
# 13        Surat
# 14        Delhi
# 15      Kolkata
# 16     Ludhiana
# 17       Kanpur
# 18    Bangalore
# 19       Kanpur
# Name: customer_city, dtype: object

# %%
amazon_india_2015_2025[['is_prime_member', 'is_prime_eligible', 'is_festival_sale']].head(20)
# Out:
#    is_prime_member is_prime_eligible is_festival_sale
# 0            False              True            False
# 1            False             False            False
# 2            False              True            False
# 3            False               Yes             True
# 4            False             False            False
# 5                0              True             True
# 6            False              True             True
# 7            False              True            FALSE
# 8            False              True             TRUE
# 9            False              True            False
# 10           False              True            False
# 11           False              True            False
# 12           False              True            False
# 13           False               Yes            False
# 14           False              TRUE             True
# 15           False             False            False
# ...

# %%
amazon_india_2015_2025['category'].sample(20)
# Out:
# 849376     Electronics
# 752131     Electronics
# 645718     Electronics
# 659563     Electronics
# 419310     Electronics
# 522798     Electronics
# 545114     Electronics
# 643084     Electronics
# 265744     Electronics
# 474680     Electronics
# 708241     Electronics
# 1072400    Electronics
# 1059433    Electronics
# 824369     Electronics
# 1078482    Electronics
# 833821     Electronics
# 567073     Electronics
# 1016301    Electronics
# 544397     Electronics
# 974119     Electronics
# Name: category, dtype: object
